# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import plotly.express as px
import numpy as np
from pytorch3d.ops import sample_farthest_points
import torch
from src.data_processing.eda_utils import show_3d_plot
from src.data_processing.dataset_utils import farthest_point_sample, pc_normalize

# %%
data_path = "../../data/modelnet40_normal_resampled/"
classes = open(data_path + "modelnet40_shape_names.txt").readlines()

# %%
shape_names = [line.rstrip() for line in open(data_path + 'modelnet40_shape_names.txt')]
c = {shape: i for i, shape in enumerate(shape_names)}
classes = dict(zip(shape_names, range(len(shape_names))))
# Out:
# {'airplane': 0,
#  'bathtub': 1,
#  'bed': 2,
#  'bench': 3,
#  'bookshelf': 4,
#  'bottle': 5,
#  'bowl': 6,
#  'car': 7,
#  'chair': 8,
#  'cone': 9,
#  'cup': 10,
#  'curtain': 11,
#  'desk': 12,
#  'door': 13,
#  'dresser': 14,
#  'flower_pot': 15,
#  'glass_box': 16,
#  'guitar': 17,
#  'keyboard': 18,
#  'lamp': 19,
#  'laptop': 20,
#  'mantel': 21,
#  'monitor': 22,
#  'night_stand': 23,
#  'person': 24,
#  'piano': 25,
#  'plant': 26,
#  'radio': 27,
#  'range_hood': 28,
#  'sink': 29,
#  'sofa': 30,
#  'stairs': 31,
#  'stool': 32,
#  'table': 33,
#  'tent': 34,
#  'toilet': 35,
#  'tv_stand': 36,
#  'vase': 37,
#  'wardrobe': 38,
#  'xbox': 39}

# %%
plane_01 = pd.read_csv(data_path + "airplane/airplane_0001.txt", header = None).to_numpy()

# %%
show_3d_plot(plane_01)

# %%
plane_01_sample = farthest_point_sample(plane_01, 1024)
plane_01_sample_normalised = pc_normalize(plane_01_sample)
show_3d_plot(plane_01_sample)
show_3d_plot(plane_01_sample_normalised)

# %%
plane_01_sample = sample_farthest_points(torch.Tensor(plane_01).unsqueeze(0), K = 1024, random_start_point=True)[0].squeeze(0).numpy()
show_3d_plot(plane_01_sample)
